# %%
from bs4 import BeautifulSoup

# %%
html = '''<html>
<head><title>My first page for web scraping</title></head>
<body>
<h> some random heading </h>
<p class = "abc"> Some random text in paragraph tag</p>
<p id = "def"> 
<a href = "https://www.youtube.com/"> YouTube link </a>
</p>
<p class = "abc">hello</p>
</html>'''

# %%
data = BeautifulSoup(html , 'html.parser')

# %%
print(data)
# Out:
# <html>
# <head><title>My first page for web scraping</title></head>
# <body>
# <h> some random heading </h>
# <p class="abc"> Some random text in paragraph tag</p>
# <p id="def">
# <a href="https://www.youtube.com/"> YouTube link </a>
# </p>
# <p class="abc">hello</p>
# </body></html>

# %%
print(data.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    My first page for web scraping
#   </title>
#  </head>
#  <body>
#   <h>
#    some random heading
#   </h>
#   <p class="abc">
#    Some random text in paragraph tag
#   </p>
#   <p id="def">
#    <a href="https://www.youtube.com/">
#     YouTube link
#    </a>
#   </p>
#   <p class="abc">
#    hello
#   </p>
#  </body>
# </html>

# %%
print(data.p)
# Out:
# <p class="abc"> Some random text in paragraph tag</p>

# %%
print(data.p.string)
# Out:
#  Some random text in paragraph tag

# %%
data.get_text()
# Out:
# '\nMy first page for web scraping\n\n some random heading \n Some random text in paragraph tag\n\n YouTube link \n\nhello\n'

# %% [markdown]
# # PRINT BODY TAG

# %%
## HTML Code is provided in variable html

html = '<!DOCTYPE html><html><head><title>Learning Beautiful Soup</title></head>\
<body><h1> About Us </h1><div class = "first_div"><p>Coding Ninjas Website</p>\
<a href="https://www.codingninjas.in/">Link to Coding Ninjas Website</a>\
<ul><li>This</li><li>is</li><li>an</li><li>unordered</li><li>list.</li></ul>\
</div><p id = "template_p">This is a template paragraph tag</p>\
<a href = "https://www.facebook.com/codingninjas/">\
This is the link of our Facebook Page</a></body></html>'

## Print the required output in given format
data = BeautifulSoup(html , 'html.parser')
data.body
# Out:
# <body><h1> About Us </h1><div class="first_div"><p>Coding Ninjas Website</p><a href="https://www.codingninjas.in/">Link to Coding Ninjas Website</a><ul><li>This</li><li>is</li><li>an</li><li>unordered</li><li>list.</li></ul></div><p id="template_p">This is a template paragraph tag</p><a href="https://www.facebook.com/codingninjas/">This is the link of our Facebook Page</a></body>

# %% [markdown]
# # DIV TAG

# %%
## HTML Code is provided in variable html

html = '<!DOCTYPE html><html><head><title>Learning Beautiful Soup</title></head>\
<body><h1> About Us </h1><div class = "first_div"><p>Coding Ninjas Website</p>\
<a href="https://www.codingninjas.in/">Link to Coding Ninjas Website</a>\
<ul><li>This</li><li>is</li><li>an</li><li>unordered</li><li>list.</li></ul>\
</div><p id = "template_p">This is a template paragraph tag</p>\
<a href = "https://www.facebook.com/codingninjas/">\
This is the link of our Facebook Page</a></body></html>'

## Print the required output in given format
data = BeautifulSoup(html , 'html.parser')

# %%
print(data.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Learning Beautiful Soup
#   </title>
#  </head>
#  <body>
#   <h1>
#    About Us
#   </h1>
#   <div class="first_div">
#    <p>
#     Coding Ninjas Website
#    </p>
#    <a href="https://www.codingninjas.in/">
#     Link to Coding Ninjas Website
#    </a>
#    <ul>
#     <li>
#      This
#     </li>
#     <li>
#      is
#     </li>
#     <li>
#      an
#     </li>
#     <li>
#      unordered
#     </li>
#     <li>
#      list.
#     </li>
#    </ul>
#   </div>
#   <p id="template_p">
#    This is a template paragraph tag
#   </p>
#   <a href="https://www.facebook.com/codingninjas/">
#    This is the link of our Facebook Page
#   </a>
#  </body>
# </html>

# %%
x = data.div
print(x.prettify())
for i in x:
    print(i.name)
print('li')
# Out:
# <div class="first_div">
#  <p>
#   Coding Ninjas Website
#  </p>
#  <a href="https://www.codingninjas.in/">
#   Link to Coding Ninjas Website
#  </a>
#  <ul>
#   <li>
#    This
#   </li>
#   <li>
#    is
#   </li>
#   <li>
#    an
#   </li>
#   <li>
#    unordered
#   </li>
#   <li>
#    list.
#   </li>
#  </ul>
# </div>
#
# p
# a
# ul
# li

# %%
print(data.title.name)
# Out:
# title

# %% [markdown]
# # ALTERNATE(ATTRIBUTES OF DIV TAG)

# %%
from bs4 import BeautifulSoup
html = '<!DOCTYPE html><html><head><title>Learning Beautiful Soup</title></head>\
<body><h1> About Us </h1><div class = "first_div"><p>Coding Ninjas Website</p>\
<a href="https://www.codingninjas.in/">Link to Coding Ninjas Website</a>\
<ul><li>This</li><li>is</li><li>an</li><li>unordered</li><li>list.</li></ul>\
</div><p id = "template_p">This is a template paragraph tag</p>\
<a href = "https://www.facebook.com/codingninjas/">\
This is the link of our Facebook Page</a></body></html>'
data=BeautifulSoup(html,'html.parser')
first_div_tag=data.div
for i in first_div_tag.attrs :
    print(i)
# Out:
# class

# %% [markdown]
# # STRINGS OF LI

# %%
## HTML Code is provided in variable html
from bs4 import BeautifulSoup

html = '<!DOCTYPE html><html><head><title>Learning Beautiful Soup</title></head>\
<body><h1> About Us </h1><div class = "first_div"><p>Coding Ninjas Website</p>\
<a href="https://www.codingninjas.in/">Link to Coding Ninjas Website</a>\
<ul><li>This</li><li>is</li><li>an</li><li>unordered</li><li>list.</li></ul>\
</div><p id = "template_p">This is a template paragraph tag</p>\
<a href = "https://www.facebook.com/codingninjas/">\
This is the link of our Facebook Page</a></body></html>'

data = BeautifulSoup(html , 'html.parser')
for i in data.find_all('li'):
    print(i.string , end = " ")
## Print the required output in given format
# Out:
# This is an unordered list.

# %% [markdown]
# # HREF OF ALL TAGS

# %%
## HTML Code is provided in variable html
from bs4 import BeautifulSoup

html = '<!DOCTYPE html><html><head><title>Learning Beautiful Soup</title></head>\
<body><h1> About Us </h1><div class = "first_div"><p>Coding Ninjas Website</p>\
<a href="https://www.codingninjas.in/">Link to Coding Ninjas Website</a>\
<ul><li>This</li><li>is</li><li>an</li><li>unordered</li><li>list.</li></ul>\
</div><p id = "template_p">This is a template paragraph tag</p>\
<a href = "https://www.facebook.com/codingninjas/">\
This is the link of our Facebook Page</a></body></html>'

data = BeautifulSoup(html , 'html.parser')

## Print the required output in given format
print(data.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Learning Beautiful Soup
#   </title>
#  </head>
#  <body>
#   <h1>
#    About Us
#   </h1>
#   <div class="first_div">
#    <p>
#     Coding Ninjas Website
#    </p>
#    <a href="https://www.codingninjas.in/">
#     Link to Coding Ninjas Website
#    </a>
#    <ul>
#     <li>
#      This
#     </li>
#     <li>
#      is
#     </li>
#     <li>
#      an
#     </li>
#     <li>
#      unordered
#     </li>
#     <li>
#      list.
#     </li>
#    </ul>
#   </div>
#   <p id="template_p">
#    This is a template paragraph tag
#   </p>
#   <a href="https://www.facebook.com/codingninjas/">
#    This is the link of our Facebook Page
#   </a>
#  </body>
# </html>

# %%
d = data.find_all('a')
for i in d:
    print(i.attrs['href'])
# Out:
# https://www.codingninjas.in/
# https://www.facebook.com/codingninjas/

# %% [markdown]
# # DESCENDANTS AND CHILDREN

# %%
from bs4 import BeautifulSoup
## HTML Code is provided in variable html

html = '<!DOCTYPE html><html><head><title>Navigate Parse Tree</title></head>\
<body><h1>This is your Assignment</h1><a href = "https://www.google.com">This is a link that will take you to Google</a>\
<ul><li><p> This question is given to test your knowledge of <b>Web Scraping</b></p>\
<p>Web scraping is a term used to describe the use of a program or algorithm to extract and process large amounts of data from the web.</p></li>\
<li id = "li2">This is an li tag given to you for scraping</li>\
<li>This li tag gives you the various ways to get data from a website\
<ol><li class = "list_or">Using API of the website</li><li>Scrape data using BeautifulSoup</li><li>Scrape data using Selenium</li>\
<li>Scrape data using Scrapy</li></ol></li>\
<li class = "list_or"><a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/">\
Clicking on this takes you to the documentation of BeautifulSoup</a>\
<a href="https://selenium-python.readthedocs.io/" id="anchor">Clicking on this takes you to the documentation of Selenium</a>\
</li></ul></body></html>'

## Print the required output in given format

data = BeautifulSoup(html , 'html.parser')
print(data.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Navigate Parse Tree
#   </title>
#  </head>
#  <body>
#   <h1>
#    This is your Assignment
#   </h1>
#   <a href="https://www.google.com">
#    This is a link that will take you to Google
#   </a>
#   <ul>
#    <li>
#     <p>
#      This question is given to test your knowledge of
#      <b>
#       Web Scraping
#      </b>
#     </p>
#     <p>
#      Web scraping is a term used to describe the use of a program or algorithm to extract and process large amounts of data from the web.
#     </p>
#    </li>
#    <li id="li2">
#     This is an li tag given to you for scraping
#    </li>
#    <li>
#     This li tag gives you the various ways to get data from a website
#     <ol>
#      <li class="list_or">
#       Using API of the website
#      </li>
#      <li>
#       Scrape data using BeautifulSoup
#      </li>
#      <li>
#       Scrape data using Selenium
#      </li>
#      <li>
#       Scrape data using Scrapy
#      </li>
# ...

# %%
desc = list(data.html.descendants)
len(desc)
# Out:
# 34

# %%
count = 0
child_it = data.html.children
for i in child_it:
    count += 1
print(count)
# Out:
# 2

# %% [markdown]
# # NAME OF TAGS WITH ID

# %%
from bs4 import BeautifulSoup
## HTML Code is provided in variable html

html = '<!DOCTYPE html><html><head><title>Navigate Parse Tree</title></head>\
<body><h1>This is your Assignment</h1><a href = "https://www.google.com">This is a link that will take you to Google</a>\
<ul><li><p> This question is given to test your knowledge of <b>Web Scraping</b></p>\
<p>Web scraping is a term used to describe the use of a program or algorithm to extract and process large amounts of data from the web.</p></li>\
<li id = "li2">This is an li tag given to you for scraping</li>\
<li>This li tag gives you the various ways to get data from a website\
<ol><li class = "list_or">Using API of the website</li><li>Scrape data using BeautifulSoup</li><li>Scrape data using Selenium</li>\
<li>Scrape data using Scrapy</li></ol></li>\
<li class = "list_or"><a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/">\
Clicking on this takes you to the documentation of BeautifulSoup</a>\
<a href="https://selenium-python.readthedocs.io/" id="anchor">Clicking on this takes you to the documentation of Selenium</a>\
</li></ul></body></html>'

## Print the required output in given format
data = BeautifulSoup(html , 'html.parser')
print(data.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Navigate Parse Tree
#   </title>
#  </head>
#  <body>
#   <h1>
#    This is your Assignment
#   </h1>
#   <a href="https://www.google.com">
#    This is a link that will take you to Google
#   </a>
#   <ul>
#    <li>
#     <p>
#      This question is given to test your knowledge of
#      <b>
#       Web Scraping
#      </b>
#     </p>
#     <p>
#      Web scraping is a term used to describe the use of a program or algorithm to extract and process large amounts of data from the web.
#     </p>
#    </li>
#    <li id="li2">
#     This is an li tag given to you for scraping
#    </li>
#    <li>
#     This li tag gives you the various ways to get data from a website
#     <ol>
#      <li class="list_or">
#       Using API of the website
#      </li>
#      <li>
#       Scrape data using BeautifulSoup
#      </li>
#      <li>
#       Scrape data using Selenium
#      </li>
#      <li>
#       Scrape data using Scrapy
#      </li>
# ...

# %%
for i in data.find_all(id = True):
    print(i.name)
# Out:
# li
# a

# %% [markdown]
# # NEXT SIBLING

# %%
from bs4 import BeautifulSoup
## HTML Code is provided in variable html

html = '<!DOCTYPE html><html><head><title>Navigate Parse Tree</title></head>\
<body><h1>This is your Assignment</h1><a href = "https://www.google.com">This is a link that will take you to Google</a>\
<ul><li><p> This question is given to test your knowledge of <b>Web Scraping</b></p>\
<p>Web scraping is a term used to describe the use of a program or algorithm to extract and process large amounts of data from the web.</p></li>\
<li id = "li2">This is an li tag given to you for scraping</li>\
<li>This li tag gives you the various ways to get data from a website\
<ol><li class = "list_or">Using API of the website</li><li>Scrape data using BeautifulSoup</li><li>Scrape data using Selenium</li>\
<li>Scrape data using Scrapy</li></ol></li>\
<li class = "list_or"><a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/">\
Clicking on this takes you to the documentation of BeautifulSoup</a>\
<a href="https://selenium-python.readthedocs.io/" id="anchor">Clicking on this takes you to the documentation of Selenium</a>\
</li></ul></body></html>'

## Print the required output in given format
soup = BeautifulSoup(html , 'html.parser')
sib = soup.find(id = "li2").next_siblings
# print(sib)
for i in sib:
    print(i)
# Out:
# <li>This li tag gives you the various ways to get data from a website<ol><li class="list_or">Using API of the website</li><li>Scrape data using BeautifulSoup</li><li>Scrape data using Selenium</li><li>Scrape data using Scrapy</li></ol></li>
# <li class="list_or"><a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/">Clicking on this takes you to the documentation of BeautifulSoup</a><a href="https://selenium-python.readthedocs.io/" id="anchor">Clicking on this takes you to the documentation of Selenium</a></li>

# %% [markdown]
# # PARENTS OF TITLE TAG

# %%
from bs4 import BeautifulSoup
## HTML Code is provided in variable html

html = '<!DOCTYPE html><html><head><title>Navigate Parse Tree</title></head>\
<body><h1>This is your Assignment</h1><a href = "https://www.google.com">This is a link that will take you to Google</a>\
<ul><li><p> This question is given to test your knowledge of <b>Web Scraping</b></p>\
<p>Web scraping is a term used to describe the use of a program or algorithm to extract and process large amounts of data from the web.</p></li>\
<li id = "li2">This is an li tag given to you for scraping</li>\
<li>This li tag gives you the various ways to get data from a website\
<ol><li class = "list_or">Using API of the website</li><li>Scrape data using BeautifulSoup</li><li>Scrape data using Selenium</li>\
<li>Scrape data using Scrapy</li></ol></li>\
<li class = "list_or"><a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/">\
Clicking on this takes you to the documentation of BeautifulSoup</a>\
<a href="https://selenium-python.readthedocs.io/" id="anchor">Clicking on this takes you to the documentation of Selenium</a>\
</li></ul></body></html>'

## Print the required output in given format
soup = BeautifulSoup(html , 'html.parser')
# print(data.prettify())
par = soup.find("title").find_parents()
# print(par)
for i in par:
    print(i)
# Out:
# <head><title>Navigate Parse Tree</title></head>
# ...

# %% [markdown]
# # NEXT ELEMENT

# %%
from bs4 import BeautifulSoup
## HTML Code is provided in variable html

html = '<!DOCTYPE html><html><head><title>Navigate Parse Tree</title></head>\
<body><h1>This is your Assignment</h1><a href = "https://www.google.com">This is a link that will take you to Google</a>\
<ul><li><p> This question is given to test your knowledge of <b>Web Scraping</b></p>\
<p>Web scraping is a term used to describe the use of a program or algorithm to extract and process large amounts of data from the web.</p></li>\
<li id = "li2">This is an li tag given to you for scraping</li>\
<li>This li tag gives you the various ways to get data from a website\
<ol><li class = "list_or">Using API of the website</li><li>Scrape data using BeautifulSoup</li><li>Scrape data using Selenium</li>\
<li>Scrape data using Scrapy</li></ol></li>\
<li class = "list_or"><a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/">\
Clicking on this takes you to the documentation of BeautifulSoup</a>\
<a href="https://selenium-python.readthedocs.io/" id="anchor">Clicking on this takes you to the documentation of Selenium</a>\
</li></ul></body></html>'

## Print the required output in given format
soup = BeautifulSoup(html , 'html.parser')
# print(soup.prettify())
last_a_tag = soup.find("a" , href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/")
print(last_a_tag.next_element)
# Out:
# Clicking on this takes you to the documentation of BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Navigate Parse Tree
#   </title>
#  </head>
#  <body>
#   <h1>
#    This is your Assignment
#   </h1>
#   <a href="https://www.google.com">
#    This is a link that will take you to Google
#   </a>
#   <ul>
#    <li>
#     <p>
#      This question is given to test your knowledge of
#      <b>
#       Web Scraping
#      </b>
#     </p>
#     <p>
#      Web scraping is a term used to describe the use of a program or algorithm to extract and process large amounts of data from the web.
#     </p>
#    </li>
#    <li id="li2">
#     This is an li tag given to you for scraping
#    </li>
#    <li>
#     This li tag gives you the various ways to get data from a website
#     <ol>
#      <li class="list_or">
#       Using API of the website
#      </li>
#      <li>
#       Scrape data using BeautifulSoup
#      </li>
#      <li>
#       Scrape data using Selenium
#      </li>
#      <li>
#       Scrape data using Scrapy
#      </li>
# ...

# %% [markdown]
# # BOOKS TO SCRAPE

# %%
import requests
response = requests.get('https://books.toscrape.com/')
print(response)
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
html = response.text
soup = BeautifulSoup(html , 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
print(soup.header)
# Out:
# <header class="header container-fluid">
# <div class="page_inner">
# <div class="row">
# <div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a><small> We love being scraped!</small>
# </div>
# </div>
# </div>
# </header>

# %%
print(soup.header.a.string)
# Out:
# Books to Scrape

# %%
b1 = soup.find(class_ = 'product_pod')
b1
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
print(b1.h3.a['title'])
# Out:
# A Light in the Attic

# %%
books = soup.find_all(class_ = 'product_pod')
print(len(books))
# Out:
# 20

# %%
for i in books:
    print(i.h3.a['title'])
# Out:
# A Light in the Attic
# Tipping the Velvet
# Soumission
# Sharp Objects
# Sapiens: A Brief History of Humankind
# The Requiem Red
# The Dirty Little Secrets of Getting Your Dream Job
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# The Black Maria
# Starving Hearts (Triangular Trade Trilogy, #1)
# Shakespeare's Sonnets
# Set Me Free
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# Rip it Up and Start Again
# Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
# Olio
# Mesaerion: The Best Science Fiction Stories 1800-1849
# Libertarianism for Beginners
# It's Only the Himalayas

# %% [markdown]
# # BOOK NAMES FROM FIRST PAGE

# %%
## Print the required output in given format
import requests
from bs4 import BeautifulSoup

response = requests.get('https://books.toscrape.com/')
html = response.text
soup = BeautifulSoup(html , 'html.parser')

b1 = soup.find(class_ = 'product_pod')
books = soup.find_all(class_ = 'product_pod')

for i in books:
    print(i.h3.a['title'])
# Out:
# A Light in the Attic
# Tipping the Velvet
# Soumission
# Sharp Objects
# Sapiens: A Brief History of Humankind
# The Requiem Red
# The Dirty Little Secrets of Getting Your Dream Job
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# The Black Maria
# Starving Hearts (Triangular Trade Trilogy, #1)
# Shakespeare's Sonnets
# Set Me Free
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# Rip it Up and Start Again
# Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
# Olio
# Mesaerion: The Best Science Fiction Stories 1800-1849
# Libertarianism for Beginners
# It's Only the Himalayas

# %% [markdown]
# # SIDEBAR CATEGORIES

# %%
import requests
from bs4 import BeautifulSoup

basic_url = 'https://books.toscrape.com/'

response = requests.get(basic_url)
html = response.text

soup = BeautifulSoup(html , 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
categories = soup.find_all(class_ = "nav nav-list")
for i in categories:
    print(i.ul.li)
# Out:
# <li>
# <a href="catalogue/category/books/travel_2/index.html">
#
#                                 Travel
#
#                         </a>
# </li>

# %%
l = ['Books','Travel','Mystery','Historical','Fiction','Sequential Art' , 'Classics' ,
    'Philosophy','Romance','Womens Fiction','Fiction','Childrens','Religion','Nonfiction',
    'Music','Default','Science Fiction' , 'Sports and Games' , 'Add a comment' , 'Fantasy',
    'New Adult' , 'Young Adult' , 'Science','Poetry', 'Paranormal' , 'Art','Psychology',
    'Autobiography' , 'Parenting' , 'Adult Fiction','Humor' , 'Horror' , 'History' , 
    'Food and Drink' , 'Christian Fiction' , 'Business' , 'Biography' , 'Thriller' , 
    'Contemporary','Spirituality','Academic','Self Help' , 'Historical','Christian','Suspense' , 
    'Short Stories' , 'Novels' , 'Health' , 'Politics' , 'Cultural' , 'Erotica' , 'Crime']
for i in l:
    print(i)
# Out:
# Books
# Travel
# Mystery
# Historical
# Fiction
# Sequential Art
# Classics
# Philosophy
# Romance
# Womens Fiction
# Fiction
# Childrens
# Religion
# Nonfiction
# Music
# Default
# Science Fiction
# Sports and Games
# Add a comment
# Fantasy
# New Adult
# Young Adult
# Science
# Poetry
# Paranormal
# Art
# Psychology
# Autobiography
# Parenting
# Adult Fiction
# Humor
# Horror
# History
# Food and Drink
# Christian Fiction
# Business
# Biography
# Thriller
# Contemporary
# Spirituality
# Academic
# Self Help
# Historical
# Christian
# Suspense
# Short Stories
# Novels
# Health
# Politics
# Cultural
# Erotica
# Crime

# %%
# I had literally written this in bruteforce , lol

# %% [markdown]
# # ALTERNATE

# %%
import requests
from bs4 import BeautifulSoup

basic_url = 'https://books.toscrape.com/'

response = requests.get(basic_url)
html = response.text

soup = BeautifulSoup(html , 'html.parser')

li = soup.find(class_ = "nav nav-list").ul

# print(li)
a = li.find_all('li')
for i in a:
    print(i.a.string.strip())
# Out:
# Travel
# Mystery
# Historical Fiction
# Sequential Art
# Classics
# Philosophy
# Romance
# Womens Fiction
# Fiction
# Childrens
# Religion
# Nonfiction
# Music
# Default
# Science Fiction
# Sports and Games
# Add a comment
# Fantasy
# New Adult
# Young Adult
# Science
# Poetry
# Paranormal
# Art
# Psychology
# Autobiography
# Parenting
# Adult Fiction
# Humor
# Horror
# History
# Food and Drink
# Christian Fiction
# Business
# Biography
# Thriller
# Contemporary
# Spirituality
# Academic
# Self Help
# Historical
# Christian
# Suspense
# Short Stories
# Novels
# Health
# Politics
# Cultural
# Erotica
# Crime

# %% [markdown]
# # LINK OF ALL PAGES

# %%
import requests
from bs4 import BeautifulSoup

all_urls = 'https://books.toscrape.com/catalogue/page-1.html'
base_url = 'https://books.toscrape.com/catalogue/'
current_page = 'https://books.toscrape.com/catalogue/page-1.html'

response = requests.get(current_page)
l = []
def getbooks(url):
    r = requests.get(url)
# print(r)
    soup = BeautifulSoup(r.text , 'html.parser')
    books = soup.find_all(class_ = 'product_pod')
    for i in books:
        print(i.h3.a['title'])
# getbooks('https://books.toscrape.com/catalogue/page-1.html')
while response.status_code == 200:
    soup = BeautifulSoup(response.text , 'html.parser')
    next_page = soup.find(class_ = 'next')
    if next_page is None:
        break
    next_page_url = base_url + next_page.a['href']
    print(next_page_url)
#     getbooks(next_page_url)
    l.append(next_page_url)
    current_page = next_page_url
    response = requests.get(current_page)
#     getbooks(next_page_url)
# for i in l:
#     getbooks(i)
# Out:
# https://books.toscrape.com/catalogue/page-2.html
# https://books.toscrape.com/catalogue/page-3.html
# https://books.toscrape.com/catalogue/page-4.html
# https://books.toscrape.com/catalogue/page-5.html
# https://books.toscrape.com/catalogue/page-6.html
# https://books.toscrape.com/catalogue/page-7.html
# https://books.toscrape.com/catalogue/page-8.html
# https://books.toscrape.com/catalogue/page-9.html
# https://books.toscrape.com/catalogue/page-10.html
# https://books.toscrape.com/catalogue/page-11.html
# https://books.toscrape.com/catalogue/page-12.html
# https://books.toscrape.com/catalogue/page-13.html
# https://books.toscrape.com/catalogue/page-14.html
# https://books.toscrape.com/catalogue/page-15.html
# https://books.toscrape.com/catalogue/page-16.html
# https://books.toscrape.com/catalogue/page-17.html
# https://books.toscrape.com/catalogue/page-18.html
# https://books.toscrape.com/catalogue/page-19.html
# https://books.toscrape.com/catalogue/page-20.html
# ...

# %%
r = requests.get('https://books.toscrape.com/')
# print(r)
soup = BeautifulSoup(r.text , 'html.parser')
books = soup.find_all(class_ = 'product_pod')
for i in books:
    print(i.h3.a['title'])

# %% [markdown]
# # ALL BOOK NAMES

# %%
## Print the required output in given format
## You are given page links in variable allPages, use this
import requests
from bs4 import BeautifulSoup
allPages = ['http://books.toscrape.com/catalogue/page-1.html',
            'http://books.toscrape.com/catalogue/page-2.html',
            'http://books.toscrape.com/catalogue/page-3.html',
            'http://books.toscrape.com/catalogue/page-4.html',
            'http://books.toscrape.com/catalogue/page-5.html',
            'http://books.toscrape.com/catalogue/page-6.html',
            'http://books.toscrape.com/catalogue/page-7.html',
            'http://books.toscrape.com/catalogue/page-8.html',
            'http://books.toscrape.com/catalogue/page-9.html',
            'http://books.toscrape.com/catalogue/page-10.html']

import requests
from bs4 import BeautifulSoup

all_urls = 'https://books.toscrape.com/catalogue/page-1.html'
base_url = 'https://books.toscrape.com/catalogue/'
current_page = 'https://books.toscrape.com/catalogue/page-1.html'

r = requests.get(current_page)
l = []
def getbooks(url):
    r = requests.get(url)
# print(r)
    soup = BeautifulSoup(r.text , 'html.parser')
    books = soup.find_all(class_ = 'product_pod')
    for i in books:
        print(i.h3.a['title'])
for i in allPages:
    getbooks(i)

# %%
##AFTER A TREMENDOUS FUCK UP AT 12.17 AM 15TH JAN I HAVE NO IDEA HOW THE FUCK I GOT 
##THE EXACT FUCKING RESULT I WAS TRYING FOR A LONG FUCKING TIME..............(BRUTE-FORCE DEBUGGING)

# %% [markdown]
# # BOOK DETAILS

# %%
import requests
import pandas as pd
import csv
import re
from bs4 import BeautifulSoup


base_url = 'https://books.toscrape.com/'

response = requests.get(base_url)
soup = BeautifulSoup(response.text , 'html.parser')

b1 = soup.find(class_ = 'product_pod')
title = b1.h3.a['title']

b1_url = base_url + b1.h3.a['href']
# print(b1_url)

# %%
r = requests.get('https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html')
print(r)

# %%
print(title)
print(b1_url)

# %%
print(price)

# %%
qty = int(re.search('\d+' , qty).group())
qty

# %%
print(title)
print(b1_url)
print(price)
print(qty)

# %%
book_details = []
book_details.append([title , b1_url , price , qty])
book_details.append([title , b1_url , price , qty])
book_details

# %%
df = pd.DataFrame(book_details , columns = ['Title' , 'Link','Price','Quantity in stock'])
df

# %%
file = df.to_csv('books.csv')

# %% [markdown]
# # BOOK DETAILS

# %%
import requests
import pandas as pd
import csv
import re
from bs4 import BeautifulSoup

allPages = ['http://books.toscrape.com/catalogue/page-1.html',
            'http://books.toscrape.com/catalogue/page-2.html']

column_names = ['Title', 'Link', 'Price', 'Quantity in Stock']
sern = []
countt = 1000
for count in range(40):
#     print(countt)
    sern.append(countt)
    count -= 1
    countt -=1 

base_url = 'http://books.toscrape.com/catalogue/'
title = []

def gettitle(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text , 'html.parser')
    books = soup.find_all(class_='product_pod')
    for i in books:
        title.append(i.h3.a['title'])
    
for i in allPages:
    gettitle(i)
# for i in title:
#     print(i)
urlr = []
def geturl(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text , 'html.parser')
    books = soup.find_all(class_ = 'product_pod')
    for i in books:
#         print(i.h3.a['href'])
        urlr.append(base_url + i.h3.a['href'])
for i in allPages:
    geturl(i)
for i in urlr:
    print(i)
# print(len(url))

# %%
# print(urlr[0])

# %%
def pricee(price):
    return float(re.search('[\d.]+',price).group())

aprice = []
aquantity = []

def qtyy(qty):
    return int(re.search('\d+' , qty).group())

basic_url = 'https://books.toscrape.com/catalogue/'
for i in urlr:
    r = requests.get(i)
#     print(r)
#     print(r.url)
    data = BeautifulSoup(r.text , 'html.parser')
    price = data.find(class_ = 'price_color').string
#     print(price)
    
    qty = data.find(class_ = 'instock availability').contents[-1].strip()
    actqty = qtyy(qty)
    actpr = pricee(price)
#     print(price , actqty)
    aprice.append(actpr)
    aquantity.append(actqty)
for i in aprice:
    print(i)
for i in aquantity:
    print(i)

# %%
for i in aprice:
    print(i)

# %%
for i in aquantity:
    print(i)

# %%
for i in title:
    print(i)

# %%
print(len(title))

# %%
for i in urlr:
    print(i)

# %%
print(len(urlr))

# %%
books = [] ## final array
for i in range(40):
    books.append([title[i] , urlr[i] , aprice[i] , aquantity[i]])

# %%
for i in books:
    print(i)

# %%
df = pd.DataFrame(books , columns = ['Title','Link','Price','Quantity in stock'])
df

# %%
file = df.to_csv('bookss.csv' , index = False)

# %%
for i in books:
    x = i
    for j in x:
        print(j , end = " ")
    print()

# %%
import requests
import pandas as pd
import csv
import re
from bs4 import BeautifulSoup

allPages = ['http://books.toscrape.com/catalogue/page-1.html',
            'http://books.toscrape.com/catalogue/page-2.html']

column_names = ['Title', 'Link', 'Price', 'Quantity in Stock']
sern = []
countt = 1000
for count in range(40):
#     print(countt)
    sern.append(countt)
    count -= 1
    countt -=1 

base_url = 'http://books.toscrape.com/'
title = []

def gettitle(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text , 'html.parser')
    books = soup.find_all(class_='product_pod')
    for i in books:
        title.append(i.h3.a['title'])
    
for i in allPages:
    gettitle(i)
# for i in title:
#     print(i)
urlr = []
def geturl(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text , 'html.parser')
    books = soup.find_all(class_ = 'product_pod')
    for i in books:
#         print(i.h3.a['href'])
        urlr.append(i.h3.a['href'])
for i in allPages:
    geturl(i)
# for i in urlr:
#     print(i)
# print(len(url))
def pricee(price):
    return float(re.search('[\d.]+',price).group())

aprice = []
aquantity = []

def qtyy(qty):
    return int(re.search('\d+' , qty).group())

basic_url = 'https://books.toscrape.com/catalogue/'
for i in urlr:
    r = requests.get(basic_url + i)
#     print(r)
#     print(r.url)
    data = BeautifulSoup(r.text , 'html.parser')
    price = data.find(class_ = 'price_color').string
    qty = data.find(class_ = 'instock availability').contents[-1].strip()
    actqty = qtyy(qty)
    actpr = pricee(price)
#     print(price , actqty)
    aprice.append(actpr)
    aquantity.append(actqty)
# for i in aprice:
#     print(i)
# for i in aquantity:
#     print(i)
books = [] ## final array
for i in range(40):
    books.append([title[i] , urlr[i] , aprice[i] , aquantity[i]])
    
for i in books:
    x = i
    for j in x:
        print(j , end = " ")
    print()

# %%
print(books)

# %%
l = [['A Light in the Attic', 'http://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html', 51.77, 22], ['Tipping the Velvet', 'http://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html', 53.74, 20], ['Soumission', 'http://books.toscrape.com/catalogue/soumission_998/index.html', 50.1, 20], ['Sharp Objects', 'http://books.toscrape.com/catalogue/sharp-objects_997/index.html', 47.82, 20], ['Sapiens: A Brief History of Humankind', 'http://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html', 54.23, 20], ['The Requiem Red', 'http://books.toscrape.com/catalogue/the-requiem-red_995/index.html', 22.65, 19], ['The Dirty Little Secrets of Getting Your Dream Job', 'http://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html', 33.34, 19], ['The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'http://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html', 17.93, 19], ['The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'http://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html', 22.6, 19], ['The Black Maria', 'http://books.toscrape.com/catalogue/the-black-maria_991/index.html', 52.15, 19], ['Starving Hearts (Triangular Trade Trilogy, #1)', 'http://books.toscrape.com/catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html', 13.99, 19], ["Shakespeare's Sonnets", 'http://books.toscrape.com/catalogue/shakespeares-sonnets_989/index.html', 20.66, 19], ['Set Me Free', 'http://books.toscrape.com/catalogue/set-me-free_988/index.html', 17.46, 19], ["Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'http://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html', 52.29, 19], ['Rip it Up and Start Again', 'http://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html', 35.02, 19], ['Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'http://books.toscrape.com/catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html', 57.25, 19], ['Olio', 'http://books.toscrape.com/catalogue/olio_984/index.html', 23.88, 19], ['Mesaerion: The Best Science Fiction Stories 1800-1849', 'http://books.toscrape.com/catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html', 37.59, 19], ['Libertarianism for Beginners', 'http://books.toscrape.com/catalogue/libertarianism-for-beginners_982/index.html', 51.33, 19], ["It's Only the Himalayas", 'http://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html', 45.17, 19], ['In Her Wake', 'http://books.toscrape.com/catalogue/in-her-wake_980/index.html', 12.84, 19], ['How Music Works', 'http://books.toscrape.com/catalogue/how-music-works_979/index.html', 37.32, 19], ['Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More', 'http://books.toscrape.com/catalogue/foolproof-preserving-a-guide-to-small-batch-jams-jellies-pickles-condiments-and-more-a-foolproof-guide-to-making-small-batch-jams-jellies-pickles-condiments-and-more_978/index.html', 30.52, 19], ['Chase Me (Paris Nights #2)', 'http://books.toscrape.com/catalogue/chase-me-paris-nights-2_977/index.html', 25.27, 19], ['Black Dust', 'http://books.toscrape.com/catalogue/black-dust_976/index.html', 34.53, 19], ['Birdsong: A Story in Pictures', 'http://books.toscrape.com/catalogue/birdsong-a-story-in-pictures_975/index.html', 54.64, 19], ["America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana", 'http://books.toscrape.com/catalogue/americas-cradle-of-quarterbacks-western-pennsylvanias-football-factory-from-johnny-unitas-to-joe-montana_974/index.html', 22.5, 19], ['Aladdin and His Wonderful Lamp', 'http://books.toscrape.com/catalogue/aladdin-and-his-wonderful-lamp_973/index.html', 53.13, 19], ['Worlds Elsewhere: Journeys Around Shakespeareâ\x80\x99s Globe', 'http://books.toscrape.com/catalogue/worlds-elsewhere-journeys-around-shakespeares-globe_972/index.html', 40.3, 18], ['Wall and Piece', 'http://books.toscrape.com/catalogue/wall-and-piece_971/index.html', 44.18, 18], ['The Four Agreements: A Practical Guide to Personal Freedom', 'http://books.toscrape.com/catalogue/the-four-agreements-a-practical-guide-to-personal-freedom_970/index.html', 17.66, 18], ['The Five Love Languages: How to Express Heartfelt Commitment to Your Mate', 'http://books.toscrape.com/catalogue/the-five-love-languages-how-to-express-heartfelt-commitment-to-your-mate_969/index.html', 31.05, 18], ['The Elephant Tree', 'http://books.toscrape.com/catalogue/the-elephant-tree_968/index.html', 23.82, 18], ['The Bear and the Piano', 'http://books.toscrape.com/catalogue/the-bear-and-the-piano_967/index.html', 36.89, 18], ["Sophie's World", 'http://books.toscrape.com/catalogue/sophies-world_966/index.html', 15.94, 18], ['Penny Maybe', 'http://books.toscrape.com/catalogue/penny-maybe_965/index.html', 33.29, 18], ['Maude (1883-1993):She Grew Up with the country', 'http://books.toscrape.com/catalogue/maude-1883-1993she-grew-up-with-the-country_964/index.html', 18.02, 18], ['In a Dark, Dark Wood', 'http://books.toscrape.com/catalogue/in-a-dark-dark-wood_963/index.html', 19.63, 18], ['Behind Closed Doors', 'http://books.toscrape.com/catalogue/behind-closed-doors_962/index.html', 52.22, 18], ["You can't bury them all: Poems", 'http://books.toscrape.com/catalogue/you-cant-bury-them-all-poems_961/index.html', 33.63, 17]]

# %%
for i in l:
    for j in i:
        print(j , end = " ")
    print()

# %% [markdown]
# # PRINT DATA OF FIRST 3 MOVIES

# %%
import requests
import pandas as pd
import csv
import re
from bs4 import BeautifulSoup


response = requests.get('https://www.imdb.com/search/title/?release_date=2018&sort=num_votes,desc&page=1&ref_=adv_nxt')
print(response)

soup = BeautifulSoup(response.text , 'html.parser')
print(soup.prettify())

# %%
title = []
s = soup.find_all(class_ = "lister-item-header")
for i in s:
    title.append(i.a.string)

# %%
genre = []
ss = soup.find_all(class_ = 'genre')
# print(ss.string.strip())
for i in ss:
    genre.append(i.string.strip())

# %%
comb = []
for i in range(3):
    print(title[i] , genre[i])

# %% [markdown]
# # TITLES WITH MOST VOTES

# %%
import requests
import pandas as pd
import csv
import re
from bs4 import BeautifulSoup

response = requests.get('https://www.imdb.com/search/title/?release_date=2010-01-01,2014-12-31&sort=num_votes,desc&start=51&ref_=adv_nxt')

# print(response)

soup = BeautifulSoup(response.text , 'html.parser')

# print(soup.prettify())

title = soup.find_all(class_ = 'lister-item-header')
for i in title:
    print(i.a.string)
# for i in title:
#     print(i)

# print(title)

# %% [markdown]
# # MAX DURATION

# %%
import requests
import pandas as pd
import csv
import re
from bs4 import BeautifulSoup

allpages = ['https://www.imdb.com/search/title/?release_date=2018&sort=num_votes,desc&page=1&ref_=adv_nxt',
           'https://www.imdb.com/search/title/?release_date=2018-01-01,2018-12-31&sort=num_votes,desc&start=51&ref_=adv_nxt',
           'https://www.imdb.com/search/title/?release_date=2018-01-01,2018-12-31&sort=num_votes,desc&start=101&ref_=adv_nxt',
           'https://www.imdb.com/search/title/?release_date=2018-01-01,2018-12-31&sort=num_votes,desc&start=151&ref_=adv_nxt',
           'https://www.imdb.com/search/title/?release_date=2018-01-01,2018-12-31&sort=num_votes,desc&start=201&ref_=adv_nxt',
           ]
dic = {}

r = requests.get('https://www.imdb.com/search/title/?release_date=2018&sort=num_votes,desc&page=1&ref_=adv_nxt')
print(r)

# %%
soup = BeautifulSoup(r.text , 'html.parser')

s = int(soup.find(class_ = 'runtime').string.split(' ')[0])
print(s)

# %%
def getdur(url):
    req = requests.get(url)
    s = soup.find_all(class_ = 'runtime')
#     title = soup.find_all(class_ = 'lister-item-header')
    for i in s:
        print(i.string.split(' ')[0])
getdur('https://www.imdb.com/search/title/?release_date=2018-01-01,2018-12-31&sort=num_votes,desc&start=51&ref_=adv_nxt')

# %%
l = ['The Haunting of Hill House 572 min' ,]

# %% [markdown]
# # APPLICATIONS OF AI

# %%
import requests
import pandas as pd
import csv
import re
from bs4 import BeautifulSoup


res = requests.get('https://en.wikipedia.org/wiki/Applications_of_artificial_intelligence')
# print(res)

soup = BeautifulSoup(res.text , 'html.parser')
# print(soup.prettify())
r = soup.find_all(class_ = 'toctext')
for i in r:
    print(i.string)

# %% [markdown]
# # IMAGE WITH MAXIMUM AREA

# %%
import requests
import pandas as pd
import csv
import re
from bs4 import BeautifulSoup


res = requests.get('https://en.wikipedia.org/wiki/Applications_of_artificial_intelligence')
base_url = 'https://en.wikipedia.org/wiki/Artificial_intelligence'
print(res)
soup = BeautifulSoup(res.text , 'html.parser')
r = soup.find_all(class_ = "thumbinner")
for i in r:
    print(int(i.a.img['height']) * int(i.a.img['width']) ,base_url + i.a['href'])
# print(r)
print('https://en.wikipedia.org/wiki/Robot-assisted_surgery#/media/File:Laproscopic_Surgery_Robot.jpg')

# %% [markdown]
# # QUOTES TO SCRAPE

# %%
import requests
import pandas as pd
import csv
import re
from bs4 import BeautifulSoup

res = requests.get('http://quotes.toscrape.com/tag/humor/')
# print(res)
soup = BeautifulSoup(res.text , 'html.parser')

s = soup.find_all(class_ = "text")
# print(s.string)
for i in s:
    print(i.string)

res = requests.get('http://quotes.toscrape.com/tag/humor/page/2/')
# print(res)
soup = BeautifulSoup(res.text , 'html.parser')

s = soup.find_all(class_ = "text")
# print(s.string)
for i in s:
    print(i.string)

# %% [markdown]
# # PRINT ALL AUTHORS

# %%
import requests
from bs4 import BeautifulSoup

all_urls = 'https://books.toscrape.com/catalogue/page-1.html'
base_url = 'https://books.toscrape.com/catalogue/'
current_page = 'https://books.toscrape.com/catalogue/page-1.html'

response = requests.get(current_page)
l = []
def getbooks(url):
    r = requests.get(url)
# print(r)
    soup = BeautifulSoup(r.text , 'html.parser')
    books = soup.find_all(class_ = 'product_pod')
    for i in books:
        print(i.h3.a['title'])
# getbooks('https://books.toscrape.com/catalogue/page-1.html')
while response.status_code == 200:
    soup = BeautifulSoup(response.text , 'html.parser')
    next_page = soup.find(class_ = 'next')
    if next_page is None:
        break
    next_page_url = base_url + next_page.a['href']
#     getbooks(next_page_url)
    l.append(next_page_url)
    current_page = next_page_url
    response = requests.get(current_page)
#     getbooks(next_page_url)
for i in l:
    getbooks(i)

# %%
import requests
import pandas as pd
import csv
import re
from bs4 import BeautifulSoup

allurls = 'http://quotes.toscrape.com/page/1/'
base_url = 'http://quotes.toscrape.com'
current_page = 'http://quotes.toscrape.com/page/1/'
print(current_page)
l = []
res = requests.get(current_page)
# print(res)
def getauthors(url):
    s = soup.find_all(class_ = "author")
    for i in s:
        print(i.string)
l = []
while res.status_code == 200:
    soup = BeautifulSoup(res.text , 'html.parser')
    next_page = soup.find(class_ = 'next')
    if next_page is None:
        break
    next_page_url = base_url + next_page.a['href']
    getauthors(current_page)
    current_page = next_page_url
    response = requests.get(current_page)
#     print(current_page)

# %%
import requests
from bs4 import BeautifulSoup as bs


response = requests.get('https://en.wikipedia.org/wiki/Artificial_intelligence')
# print(response)
soup = bs(response.text , 'html.parser')
# b = soup.find(class_ = "thumbinner")
# print(b.a.img["src"] , float(b.a.img["height"])*float(b.a.img["width"]))

dict_ = {}
bb = soup.find_all(class_ = "thumbinner")
for i in bb:
    src = i.a.img["src"]
    area = float(i.a.img["height"])*float(i.a.img["width"])
    if src not in dict_:
        dict_[src] = area
s = dict(sorted(dict_.items() , key = lambda item:item[1] , reverse = True)[0:1])
for i in s:
    print(i)
# Out:
# //upload.wikimedia.org/wikipedia/commons/thumb/1/13/Joseph_Ayerle_portrait_of_Ornella_Muti_%28detail%29%2C_calculated_by_Artificial_Intelligence_%28AI%29_technology.jpg/220px-Joseph_Ayerle_portrait_of_Ornella_Muti_%28detail%29%2C_calculated_by_Artificial_Intelligence_%28AI%29_technology.jpg

# %% [markdown]
# # BIRTH DATE OF AUTHORS

# %%
l = ['J.D. Salinger','J.K. Rowling','J.M. Barrie','J.R.R. Tolkien','James Baldwin','Jane Austen','Jim Henson','Jimi Hendrix','John Lennon','Jorge Luis Borges']

# %%
import requests
from bs4 import BeautifulSoup as bs

base_url = 'https://quotes.toscrape.com/'
current_page = 'https://quotes.toscrape.com/'
dict_ = {}
x = []
response = requests.get(current_page)
while response.status_code == 200:
    soup = bs(response.text , 'html.parser')

    s = soup.find_all(class_ = "quote")
# print(s.small.string)
# print(s.a['href'])
# print(s.small.string)
    for i in s:
        if i.small.string[0] == 'J':
            urll = base_url + i.a['href']
            x.append(urll)
    next_page = soup.find(class_ = "next")
    if next_page is None:
        break
    next_page_url = base_url + next_page.a["href"]
    current_page = next_page_url
    response = requests.get(current_page)
#         print(i.small.string)
# for i in x:
#     print(i)
for i in x:
    response = requests.get(i)
    soup = bs(response.text , 'html.parser')
    e = soup.find(class_ = "author-born-date")
#     dict_[e.string]
    print(e.string)
# Out:
# July 31, 1965
# December 16, 1775
# July 31, 1965
# September 24, 1936
# July 31, 1965
# July 31, 1965
# July 31, 1965
# August 24, 1899
# July 31, 1965
# August 02, 1924
# December 16, 1775
# January 03, 1892
# July 31, 1965
# January 01, 1919
# October 09, 1940
# December 16, 1775
# July 31, 1965
# December 16, 1775
# December 16, 1775
# July 31, 1965
# November 27, 1942
# May 09, 1860

# %%
f = ['https://quotes.toscrape.com/author/J-D-Salinger/' , 
    'https://quotes.toscrape.com/author/J-K-Rowling/' , 
    'https://quotes.toscrape.com/author/J-M-Barrie/' , 
    'https://quotes.toscrape.com/author/J-R-R-Tolkien/' , 
    'https://quotes.toscrape.com/author/James-Baldwin/' , 
    'https://quotes.toscrape.com/author/Jane-Austen/' , 
    'https://quotes.toscrape.com/author/Jim-Henson/' , 
    'https://quotes.toscrape.com/author/Jimi-Hendrix/' , 
    'https://quotes.toscrape.com/author/John-Lennon/' , 
    'https://quotes.toscrape.com/author/Jorge-Luis-Borges/']

dict_ = {}

# print(f[0])
for i in range(len(f)):
    r = requests.get(f[i])
    soup = bs(r.text , 'html.parser')
    d = soup.find(class_ = "author-born-date")
    dict_[l[i]] = d.string
# for i in dict_:
#     print(i)
print(dict_)
# Out:
# https://quotes.toscrape.com/author/J-D-Salinger/
# {'J.D. Salinger': 'January 01, 1919', 'J.K. Rowling': 'July 31, 1965', 'J.M. Barrie': 'May 09, 1860', 'J.R.R. Tolkien': 'January 03, 1892', 'James Baldwin': 'August 02, 1924', 'Jane Austen': 'December 16, 1775', 'Jim Henson': 'September 24, 1936', 'Jimi Hendrix': 'November 27, 1942', 'John Lennon': 'October 09, 1940', 'Jorge Luis Borges': 'August 24, 1899'}

# %% [markdown]
# # TITLE WITH MAXIMUM DURATION

# %%
import requests
from bs4 import BeautifulSoup as bs

f = ['https://www.imdb.com/search/title/?release_date=2018&sort=num_votes,desc&page=1&ref_=adv_nxt',
    'https://www.imdb.com/search/title/?release_date=2018-01-01,2018-12-31&sort=num_votes,desc&start=51&ref_=adv_nxt',
    'https://www.imdb.com/search/title/?release_date=2018-01-01,2018-12-31&sort=num_votes,desc&start=101&ref_=adv_nxt',
    'https://www.imdb.com/search/title/?release_date=2018-01-01,2018-12-31&sort=num_votes,desc&start=151&ref_=adv_nxt',
    'https://www.imdb.com/search/title/?release_date=2018-01-01,2018-12-31&sort=num_votes,desc&start=201&ref_=adv_nxt',
    ]

# response = requests.get('https://www.imdb.com/search/title/?release_date=2018-01-01,2018-12-31&sort=num_votes,desc&ref_=adv_prv')
# print(response)



dict_ = {}
for i in range(len(f)):
    r = requests.get(f[i])
    soup = bs(r.text , 'html.parser')
    d = soup.find_all(class_ = "lister-item-content")
    dd = soup.find_all(class_ = "runtime")
    titles = []
# print(int(d.string.strip().split(' ')[0]))
    for i in d:
        titles.append(i.h3.a.string)
    runtimes = []
    for i in dd:
        runtimes.append(int(i.string.strip().split(' ')[0]))

    for i in range(len(titles)):
        if titles[i] not in dict_:
            dict_[titles[i]] = runtimes[i]
s = dict(sorted(dict_.items() , key = lambda item:item[1] , reverse = True)[0:1])

for i in s:
    print(i, s[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-85-6e70ce7c3d04> in <module>
#      30     for i in range(len(titles)):
#      31         if titles[i] not in dict_:
# ---> 32             dict_[titles[i]] = runtimes[i]
#      33 s = dict(sorted(dict_.items() , key = lambda item:item[1] , reverse = True)[0:1])
#      34
#
# IndexError: list index out of range

# %%
for i in s:
    print(i , s[i])
# Out:
# The Haunting of Hill House 572
